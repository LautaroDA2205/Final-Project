# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env", override=True)

print(os.getenv("FMP_API_KEY"))
# Out:
# API: None
# /Users/lautarocardinisilvestri/Documents/GitHub/Final-Project/.env
# True

# %%
from dotenv import dotenv_values

config = dotenv_values("../../.env")
print(config)
# Out:
# OrderedDict()

# %%
import dotenv
print(dotenv.__file__)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/dotenv/__init__.py
